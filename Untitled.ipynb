# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\task3datacleaning\DataClean - DataClean.csv.csv")
df
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance  owner    price       location  mileage  \
# ...

# %%
df.shape
# Out:
# (32200, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32200 entries, 0 to 32199
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    32200 non-null  int64
#  1   brand         32199 non-null  object
#  2   model         32199 non-null  object
#  3   transmission  32200 non-null  object
#  4   age           32199 non-null  float64
#  5   fuel          32200 non-null  object
#  6   engine        24068 non-null  float64
#  7   Distance      32200 non-null  object
#  8   owner         16819 non-null  float64
#  9   price         32200 non-null  int64
#  10  location      13801 non-null  object
#  11  mileage       21380 non-null  float64
#  12  power         21273 non-null  float64
#  13  seats         29353 non-null  float64
#  14  type          8015 non-null   object
# dtypes: float64(6), int64(2), object(7)
# memory usage: 3.7+ MB

# %%
df.isnull()#for finding the unknown values
# Out:
#        Unnamed: 0  brand  model  transmission    age   fuel  engine  Distance  \
# 0           False  False  False         False  False  False    True     False
# 1           False  False  False         False  False  False   False     False
# 2           False  False  False         False  False  False   False     False
# 3           False  False  False         False  False  False   False     False
# 4           False  False  False         False  False  False    True     False
# ...           ...    ...    ...           ...    ...    ...     ...       ...
# 32195       False  False  False         False  False  False   False     False
# 32196       False  False  False         False  False  False   False     False
# 32197       False  False  False         False  False  False   False     False
# 32198       False  False  False         False  False  False    True     False
# 32199       False  False  False         False  False  False   False     False
#
# ...

# %%
df.isnull().sum()# for finding how many unknown datas are
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# Distance            0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64

# %%
df1=(df.isnull().sum()/df.shape[0])*100
df1
# Out:
# Unnamed: 0       0.000000
# brand            0.003106
# model            0.003106
# transmission     0.000000
# age              0.003106
# fuel             0.000000
# engine          25.254658
# Distance         0.000000
# owner           47.767081
# price            0.000000
# location        57.139752
# mileage         33.602484
# power           33.934783
# seats            8.841615
# type            75.108696
# dtype: float64

# %%
df.describe()
# Out:
#         Unnamed: 0           age        engine         owner         price  \
# count  32200.00000  32199.000000  24068.000000  16819.000000  3.220000e+04
# mean   16099.50000      7.120625   1489.872569      1.263452  7.347001e+05
# std     9295.48367      3.485577    520.916872      0.490463  7.037702e+05
# min        0.00000      0.000000     72.000000      1.000000  4.000000e+04
# 25%     8049.75000      4.000000   1197.000000      1.000000  3.850000e+05
# 50%    16099.50000      7.000000   1248.000000      1.000000  5.510000e+05
# 75%    24149.25000      9.000000   1591.000000      1.000000  7.920000e+05
# max    32199.00000     29.000000   5998.000000      4.000000  7.066000e+06
#
#             mileage         power         seats
# count  21380.000000  21273.000000  29353.000000
# mean      19.305532    103.497647      5.233537
# std        4.418605     45.002260      0.707639
# min        0.000000     34.200000      0.000000
# 25%       16.500000     74.000000      5.000000
# ...

# %%
plt.figure(figsize=(25,25))#for figure 
sns.heatmap(df.isnull())#to draw the heat map of the overall data 25*25 inches
# Out:
# <Axes: >

# %%
drop_columns = df1[df1>47].keys()#.keys or .index retrieve the column
drop_columns
# Out:
# Index(['owner', 'location', 'type'], dtype='object')

# %%
df2=df.drop(columns=drop_columns)
df2
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price  mileage   power  seats
# ...

# %%
df2.shape
# Out:
# (32200, 12)

# %%
sns.heatmap(df2.isnull())
# Out:
# <Axes: >

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32200 entries, 0 to 32199
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    32200 non-null  int64
#  1   brand         32199 non-null  object
#  2   model         32199 non-null  object
#  3   transmission  32200 non-null  object
#  4   age           32199 non-null  float64
#  5   fuel          32200 non-null  object
#  6   engine        24068 non-null  float64
#  7   Distance      32200 non-null  object
#  8   price         32200 non-null  int64
#  9   mileage       21380 non-null  float64
#  10  power         21273 non-null  float64
#  11  seats         29353 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 2.9+ MB

# %%
df2.isnull()
# Out:
#        Unnamed: 0  brand  model  transmission    age   fuel  engine  Distance  \
# 0           False  False  False         False  False  False    True     False
# 1           False  False  False         False  False  False   False     False
# 2           False  False  False         False  False  False   False     False
# 3           False  False  False         False  False  False   False     False
# 4           False  False  False         False  False  False    True     False
# ...           ...    ...    ...           ...    ...    ...     ...       ...
# 32195       False  False  False         False  False  False   False     False
# 32196       False  False  False         False  False  False   False     False
# 32197       False  False  False         False  False  False   False     False
# 32198       False  False  False         False  False  False    True     False
# 32199       False  False  False         False  False  False   False     False
#
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# Distance            0
# price               0
# mileage         10820
# power           10927
# seats            2847
# dtype: int64

# %%
df2[df2['brand'].isnull()] #finding any row in any column to check the missing data
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine    Distance  \
# 1817        1817   NaN   NaN    automatic  NaN  petrol     NaN  13794.0 KM
#
#        price  mileage  power  seats
# 1817  976000      NaN    NaN    5.0

# %%
df3=df2.drop(1817)# to delete the row
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price  mileage   power  seats
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model               0
# transmission        0
# age                 0
# fuel                0
# engine           8131
# Distance            0
# price               0
# mileage         10819
# power           10926
# seats            2847
# dtype: int64

# %%
df3['seats']=df3['seats'].fillna(5)#to fill all the values in any column

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model               0
# transmission        0
# age                 0
# fuel                0
# engine           8131
# Distance            0
# price               0
# mileage         10819
# power           10926
# seats               0
# dtype: int64

# %%
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price  mileage   power  seats
# ...

# %%
df3.head(20)
# Out:
#     Unnamed: 0          brand     model transmission   age    fuel  engine  \
# 0            0     volkswagen      ameo       manual   8.0  diesel     NaN
# 1            1        renault    duster       manual   8.0  diesel  1461.0
# 2            2           land     rover    automatic  21.0  diesel  1197.0
# 3            3  mercedes-benz       new    automatic  10.0  diesel  2143.0
# 4            4         maruti      alto       manual   4.0     cng     NaN
# 5            5        hyundai       i20       manual   4.0  petrol  1197.0
# 6            6           audi        a4    automatic  11.0  petrol  1984.0
# 7            7         maruti     swift       manual   9.0  petrol  1197.0
# 8            8          honda      city       manual  11.0  diesel     NaN
# 9            9         maruti  alto k10       manual  13.0  petrol     NaN
# 10          10          honda      city       manual   5.0  petrol  1497.0
# ...

# %%
df3.describe()
# Out:
#          Unnamed: 0           age        engine         price       mileage  \
# count  32199.000000  32199.000000  24068.000000  3.219900e+04  21380.000000
# mean   16099.943570      7.120625   1489.872569  7.346926e+05     19.305532
# std     9295.287224      3.485577    520.916872  7.037798e+05      4.418605
# min        0.000000      0.000000     72.000000  4.000000e+04      0.000000
# 25%     8050.500000      4.000000   1197.000000  3.850000e+05     16.500000
# 50%    16100.000000      7.000000   1248.000000  5.510000e+05     19.010000
# 75%    24149.500000      9.000000   1591.000000  7.920000e+05     22.320000
# max    32199.000000     29.000000   5998.000000  7.066000e+06     46.620600
#
#               power         seats
# count  21273.000000  32199.000000
# mean     103.497647      5.212895
# std       45.002260      0.678886
# min       34.200000      0.000000
# 25%       74.000000      5.000000
# 50%       88.500000      5.000000
# 75%      120.000000      5.000000
# ...

# %%
df3['mileage']=df3['mileage'].fillna(19.305532)#or(df3['mileage'].mean())

# %%
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price    mileage   power  seats
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model               0
# transmission        0
# age                 0
# fuel                0
# engine           8131
# Distance            0
# price               0
# mileage             0
# power           10926
# seats               0
# dtype: int64

# %%
df3['power']=df3['power'].fillna(df3['power'].median())

# %%
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price    mileage   power  seats
# ...

# %%
#df3['mileage']=df3['mileage'].replace(0,10) to replace any value
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price    mileage   power  seats
# ...

# %%
df3['engine'].head(50)
# Out:
# 0        NaN
# 1     1461.0
# 2     1197.0
# 3     2143.0
# 4        NaN
# 5     1197.0
# 6     1984.0
# 7     1197.0
# 8        NaN
# 9        NaN
# 10    1497.0
# 11     999.0
# 12    1198.0
# 13       NaN
# 14    1197.0
# 15       NaN
# 16    1353.0
# 17    1120.0
# 18    1199.0
# 19    1461.0
# 20     998.0
# 21    1248.0
# 22       NaN
# 23    1298.0
# 24    1086.0
# 25    1248.0
# 26       NaN
# 27     998.0
# 28     998.0
# 29       NaN
# 30    1197.0
# 31       NaN
# 32     998.0
# 33    1373.0
# 34    1968.0
# 35       NaN
# 36       NaN
# 37    1461.0
# 38       NaN
# 39    2143.0
# 40    2179.0
# 41    1199.0
# 42    1498.0
# 43    1591.0
# 44    1497.0
# 45     999.0
# 46    1196.0
# 47    1461.0
# 48    2179.0
# 49    2199.0
# Name: engine, dtype: float64

# %%
df3['engine'].mode()
# Out:
# 0    1197.0
# Name: engine, dtype: float64

# %%
(df3['engine']==1197).sum()# to find that how many times mode value came
# Out:
# 3845

# %%
df3['engine']=df3['engine'].fillna(1197)

# %%
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price    mileage   power  seats
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0      0
# brand           0
# model           0
# transmission    0
# age             0
# fuel            0
# engine          0
# Distance        0
# price           0
# mileage         0
# power           0
# seats           0
# dtype: int64

# %%
df3
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance    price    mileage   power  seats
# ...
